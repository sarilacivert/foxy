# %% [markdown]
# # Daily Forecast

# %%
# Required imports
import pandas as pd
import matplotlib.pyplot as plt

# Modeling Package
from neuralprophet import NeuralProphet

# %%
df = pd.read_csv('daily10.csv')

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15130 entries, 0 to 15129
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    15130 non-null  object
#  1   DGS10   15130 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 354.6+ KB

# %%
df.columns = ['ds', 'y']
list(df.columns.values)
# Out:
# ['ds', 'y']

# %%
df.head()
# Out:
#            ds     y
# 0  1962-01-02  4.06
# 1  1962-01-03  4.03
# 2  1962-01-04  3.99
# 3  1962-01-05  4.02
# 4  1962-01-08  4.03

# %%
df.tail()
# Out:
#                ds     y
# 15125  2022-07-25  2.81
# 15126  2022-07-26  2.81
# 15127  2022-07-27  2.78
# 15128  2022-07-28  2.68
# 15129  2022-07-29  2.67

# %%
df.describe()
# Out:
#                   y
# count  15130.000000
# mean       5.918515
# std        2.991581
# min        0.520000
# 25%        3.900000
# 50%        5.720000
# 75%        7.670000
# max       15.840000

# %%
m = NeuralProphet(
    daily_seasonality = True,
    learning_rate=0.1)

# %%
metrics = m.fit(df, freq="D")
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 95.578% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 64
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 92
# Epoch[92/92]: 100%|█| 92/92 [00:30<00:00,  3.02it/s, SmoothL1Loss=0.00206, MAE=0

# %%
future = m.make_future_dataframe(df=df, periods=30)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 95.578% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D

# %%
forecast = m.predict(df=future)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 96.667% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D
# INFO - (NP.df_utils._infer_frequency) - Major frequency D corresponds to 96.667% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - D

# %%
forecast.head()
# Out:
#           ds     y     yhat1 residual1     trend  season_yearly  \
# 0 2022-07-30  None -0.477536       NaN -4.069495       0.045017
# 1 2022-07-31  None -0.411258       NaN -4.069698       0.043324
# 2 2022-08-01  None  1.739927       NaN -4.069901       0.041613
# 3 2022-08-02  None  1.758913       NaN -4.070105       0.039888
# 4 2022-08-03  None  1.750379       NaN -4.070309       0.038156
#
#    season_weekly  season_daily
# 0      -1.603843      5.150785
# 1      -1.535669      5.150785
# 2       0.617431      5.150785
# 3       0.638345      5.150785
# 4       0.631747      5.150785

# %% [markdown]
# ### Plotting

# %%
fig_forecast = m.plot(forecast)

# %%
fig_comp = m.plot_components(forecast)

# %% [markdown]
# #### The financial markets are not open on the weekend, and there is less economic activity in the winter months so the above lineplots are reasonable.

# %%
fig_param = m.plot_parameters()

# %% [markdown]
# ## Validation

# %%
# Manual Split
m = NeuralProphet()
df_train, df_test = m.split_df(df, valid_p=0.2)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 95.578% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as B

# %%
train_metrics = m.fit(df_train)
test_metrics = m.test(df_test)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 95.547% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as B
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 64
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 98
#   0%|          | 0/152 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 7.96E-02, min: 1.63E+00
#   0%|          | 0/152 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 6.94E-02, min: 1.24E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 8.20E-02
# Epoch[98/98]: 100%|█| 98/98 [00:24<00:00,  3.99it/s, SmoothL1Loss=0.00233, MAE=0
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 95.671% of the data.
# INFO - (NP.df_utils._infer_frequency) - Defined frequency is equal to major frequency - B
# INFO - (NP.forecaster._evaluate) - Validation metrics:    SmoothL1Loss    MAE   RMSE
# 1         0.003  0.673  0.797

# %%
# Builtin Function

m = NeuralProphet()
metrics = m.fit(df_train, validation_df=df_test)
# Out:
# INFO - (NP.df_utils._infer_frequency) - Major frequency B corresponds to 95.547% of the data.
# INFO - (NP.df_utils._infer_frequency) - Dataframe freq automatically defined as B
# INFO - (NP.config.init_data_params) - Setting normalization to global as only one dataframe provided for training.
# INFO - (NP.utils.set_auto_seasonalities) - Disabling daily seasonality. Run NeuralProphet with daily_seasonality=True to override this.
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 64
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set epochs to 98
#   0%|          | 0/152 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 6.05E-02, min: 2.14E+00
#   0%|          | 0/152 [00:00<?, ?it/s]
# INFO - (NP.utils_torch.lr_range_test) - lr-range-test results: steep: 6.94E-02, min: 1.42E+00
# INFO - (NP.forecaster._init_train_loader) - lr-range-test selected learning rate: 7.48E-02
# Epoch[98/98]: 100%|█| 98/98 [00:25<00:00,  3.89it/s, SmoothL1Loss=0.00233, MAE=0

# %%
fig, ax = plt.subplots(figsize=(20, 8))
ax.plot(metrics["MAE"], '-o', label="Training Loss")  
ax.plot(metrics["MAE_val"], '-r', label="Validation Loss")
ax.legend(loc='center right', fontsize=16)
ax.tick_params(axis='both', which='major', labelsize=20)
ax.set_xlabel("Epoch", fontsize=28)
ax.set_ylabel("Loss", fontsize=28)
ax.set_title("Model Loss (MAE) with Daily Frequency", fontsize=28)
# Out:
# Text(0.5, 1.0, 'Model Loss (MAE) with Daily Frequency')
